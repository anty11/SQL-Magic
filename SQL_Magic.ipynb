# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://gqs15811:05%5Ep55nfbkvqx0ch@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CHICAGO_CRIME_DATA', 'GQS15811', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2020, 12, 27, 12, 51, 20, 886660), datetime.datetime(2020, 12, 27, 12, 51, 20, 886660), datetime.datetime(2020, 12, 27, 12, 51, 20, 886660), datetime.datetime(2020, 12, 27, 13, 2, 50, 192045), 22, 16, 699, 533, 4, 0, 5, -1, -1, -1, 0, 'gqs15811space1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 241, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2020, 12, 27, 12, 51, 20, 886660), 0, ' ', None, None, 'N', 'GQS15811', ' ', ' ', ' ', datetime.date(2020, 12, 27), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CHICAGO_PUBLIC_SCHOOLS', 'GQS15811', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2020, 12, 27, 12, 37, 19, 94407), datetime.datetime(2020, 12, 27, 12, 37, 19, 94407), datetime.datetime(2020, 12, 27, 12, 37, 19, 94407), datetime.datetime(2020, 12, 27, 12, 37, 49, 560873), 78, 15, 699, 566, 15, 0, 16, -1, -1, -1, 0, 'gqs15811space1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 844, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2020, 12, 27, 12, 37, 19, 94407), 0, ' ', None, None, 'N', 'GQS15811', ' ', ' ', ' ', datetime.date(2020, 12, 27), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CENSUS_DATA', 'GQS15811', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2020, 12, 27, 12, 35, 40, 95904), datetime.datetime(2020, 12, 27, 12, 35, 40, 95904), datetime.datetime(2020, 12, 27, 12, 35, 40, 95904), datetime.datetime(2020, 12, 27, 12, 47, 49, 773198), 9, 14, 699, 78, 1, 0, 2, -1, -1, -1, 0, 'gqs15811space1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 57, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2020, 12, 27, 12, 35, 40, 95904), 0, ' ', None, None, 'N', 'GQS15811', ' ', ' ', ' ', datetime.date(2020, 12, 27), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('22'),)]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('78'),)]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('9'),)]

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ID', 'INTEGER', 4),
#  ('CASE_NUMBER', 'VARCHAR', 8),
#  ('DATE', 'TIMESTAMP', 10),
#  ('BLOCK', 'VARCHAR', 35),
#  ('IUCR', 'VARCHAR', 4),
#  ('PRIMARY_TYPE', 'VARCHAR', 33),
#  ('DESCRIPTION', 'VARCHAR', 46),
#  ('LOCATION_DESCRIPTION', 'VARCHAR', 33),
#  ('ARREST', 'VARCHAR', 5),
#  ('DOMESTIC', 'VARCHAR', 5),
#  ('BEAT', 'SMALLINT', 2),
#  ('DISTRICT', 'SMALLINT', 2),
#  ('WARD', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('FBICODE', 'VARCHAR', 3),
#  ('X_COORDINATE', 'INTEGER', 4),
#  ('Y_COORDINATE', 'INTEGER', 4),
#  ('YEAR', 'SMALLINT', 2),
#  ('UPDATEDON', 'TIMESTAMP', 10),
#  ('LATITUDE', 'DECIMAL', 18),
#  ('LONGITUDE', 'DECIMAL', 18),
#  ('LOCATION', 'VARCHAR', 29)]

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('School_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 65),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Street_Address', 'VARCHAR', 30),
#  ('City', 'VARCHAR', 7),
#  ('State', 'VARCHAR', 2),
#  ('ZIP_Code', 'INTEGER', 4),
#  ('Phone_Number', 'VARCHAR', 14),
#  ('Link', 'VARCHAR', 78),
#  ('Network_Manager', 'VARCHAR', 40),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Track_Schedule', 'VARCHAR', 12),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('Safety_Icon', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('Family_Involvement_Icon', 'VARCHAR', 11),
#  ('Family_Involvement_Score', 'VARCHAR', 3),
#  ('Environment_Icon', 'VARCHAR', 11),
#  ('Environment_Score', 'SMALLINT', 2),
# ...

# %%
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR', 22),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DECIMAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'DECIMAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'DECIMAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'DECIMAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'DECIMAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 4),
#  ('HARDSHIP_INDEX', 'SMALLINT', 2)]

# %%
# %sql select * FROM SYSCAT.COLUMNS WHERE TABNAME = 'CHICAGO_CRIME_DATA' LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CHICAGO_CRIME_DATA', 'ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 533, '11233321', '23469', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('GQS15811', 'CHICAGO_CRIME_DATA', 'CASE_NUMBER', 1, 'SYSIBM  ', 'VARCHAR', 8, 0, 'OCTETS', 8, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 533, "'JB155558'", "'G040244'", 13, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 8, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select * FROM SYSCAT.COLUMNS WHERE TABNAME = 'CHICAGO_PUBLIC_SCHOOLS' LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CHICAGO_PUBLIC_SCHOOLS', 'School_ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 566, '610543', '609674', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('GQS15811', 'CHICAGO_PUBLIC_SCHOOLS', 'NAME_OF_SCHOOL', 1, 'SYSIBM  ', 'VARCHAR', 65, 0, 'OCTETS', 65, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 566, "'Woodlawn Community Elementary Sch'", "'Abraham Lincoln Elementary School'", 41, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 36, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select * FROM SYSCAT.COLUMNS WHERE TABNAME = 'CENSUS_DATA'  LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('GQS15811', 'CENSUS_DATA', 'COMMUNITY_AREA_NUMBER', 0, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '77', '2', 3, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('GQS15811', 'CENSUS_DATA', 'COMMUNITY_AREA_NAME', 1, 'SYSIBM  ', 'VARCHAR', 22, 0, 'OCTETS', 22, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 78, "'West Town'", "'Archer Heights'", 16, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 11, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select COUNT(*) from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql select * from CHICAGO_CRIME_DATA LIMIT 10
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', datetime.datetime(2004, 8, 28, 17, 50, 56), '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, datetime.datetime(2018, 2, 10, 15, 50, 1), Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', datetime.datetime(2004, 6, 26, 12, 40), '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, datetime.datetime(2018, 2, 28, 15, 56, 25), Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %%
# %sql select COUNT(*) FROM CHICAGO_CRIME_DATA WHERE ARREST = 'TRUE'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('163'),)]

# %%
# %sql select PRIMARY_TYPE FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION = 'GAS STATION'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('THEFT',),
#  ('THEFT',),
#  ('NARCOTICS',),
#  ('ROBBERY',),
#  ('ROBBERY',),
#  ('CRIMINAL TRESPASS',)]

# %%
# %sql SELECT DISTINCT PRIMARY_TYPE FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION = 'GAS STATION'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('CRIMINAL TRESPASS',), ('NARCOTICS',), ('ROBBERY',), ('THEFT',)]

# %%
# %sql select COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE COMMUNITY_AREA_NAME LIKE 'B%'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %%
# %sql select * FROM CENSUS_DATA LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(1, 'Rogers Park', Decimal('7.7'), Decimal('23.6'), Decimal('8.7'), Decimal('18.2'), Decimal('27.5'), 23939, 39),
#  (2, 'West Ridge', Decimal('7.8'), Decimal('17.2'), Decimal('8.8'), Decimal('20.8'), Decimal('38.5'), 23040, 46),
#  (3, 'Uptown', Decimal('3.8'), Decimal('24.0'), Decimal('8.9'), Decimal('11.8'), Decimal('22.2'), 35787, 20),
#  (4, 'Lincoln Square', Decimal('3.4'), Decimal('10.9'), Decimal('8.2'), Decimal('13.4'), Decimal('25.5'), 37524, 17),
#  (5, 'North Center', Decimal('0.3'), Decimal('7.5'), Decimal('5.2'), Decimal('4.5'), Decimal('26.2'), 57123, 6)]

# %%
# %sql select * FROM CHICAGO_PUBLIC_SCHOOLS LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql select * FROM CHICAGO_PUBLIC_SCHOOLS WHERE COMMUNITY_AREA_NUMBER LIKE '10' AND HEALTHY_SCHOOL_CERTIFIED = 'Yes'
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql select NAME_OF_SCHOOL, COMMUNITY_AREA_NUMBER, HEALTHY_SCHOOL_CERTIFIED\
FROM CHICAGO_PUBLIC_SCHOOLS\
WHERE HEALTHY_SCHOOL_CERTIFIED = 'Yes' \
AND 9 < COMMUNITY_AREA_NUMBER \
AND 15 > COMMUNITY_AREA_NUMBER
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql SELECT AVG(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %%
# %sql SELECT COMMUNITY_AREA_NAME, COLLEGE_ENROLLMENT \
FROM CHICAGO_PUBLIC_SCHOOLS \
ORDER BY COMMUNITY_AREA_NAME
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', 266),
#  ('ALBANY PARK', 1023),
#  ('ALBANY PARK', 1299),
#  ('ALBANY PARK', 919),
#  ('ALBANY PARK', 359),
#  ('ALBANY PARK', 1490),
#  ('ALBANY PARK', 269),
#  ('ALBANY PARK', 1239),
#  ('ARCHER HEIGHTS', 3320),
#  ('ARCHER HEIGHTS', 1503),
#  ('ARMOUR SQUARE', 302),
#  ('ARMOUR SQUARE', 492),
#  ('ARMOUR SQUARE', 664),
#  ('ASHBURN', 1324),
#  ('ASHBURN', 490),
#  ('ASHBURN', 537),
#  ('ASHBURN', 1032),
#  ('ASHBURN', 543),
#  ('ASHBURN', 658),
#  ('ASHBURN', 243),
#  ('ASHBURN', 1656),
#  ('AUBURN GRESHAM', 602),
#  ('AUBURN GRESHAM', 418),
#  ('AUBURN GRESHAM', 237),
#  ('AUBURN GRESHAM', 482),
#  ('AUBURN GRESHAM', 323),
#  ('AUBURN GRESHAM', 512),
#  ('AUBURN GRESHAM', 402),
#  ('AUBURN GRESHAM', 538),
#  ('AUBURN GRESHAM', 359),
#  ('AUBURN GRESHAM', 302),
#  ('AUSTIN', 316),
#  ('AUSTIN', 250),
#  ('AUSTIN', 377),
#  ('AUSTIN', 1111),
#  ('AUSTIN', 301),
# ...

# %%
# %sql SELECT COMMUNITY_AREA_NAME, AVG(COLLEGE_ENROLLMENT) AS AVERAGE_COLLEGE_ENROLLMENT \
FROM CHICAGO_PUBLIC_SCHOOLS \
GROUP BY COMMUNITY_AREA_NAME \
ORDER BY AVERAGE_COLLEGE_ENROLLMENT DESC\
LIMIT 5
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', Decimal('858.000000')),
#  ('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('ARMOUR SQUARE', Decimal('486.000000')),
#  ('ASHBURN', Decimal('810.375000')),
#  ('AUBURN GRESHAM', Decimal('417.500000')),
#  ('AUSTIN', Decimal('475.347826')),
#  ('AVALON PARK', Decimal('507.333333')),
#  ('AVONDALE', Decimal('910.000000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333')),
#  ('BEVERLY', Decimal('409.000000')),
#  ('BRIDGEPORT', Decimal('633.400000')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BURNSIDE', Decimal('549.000000')),
#  ('CALUMET HEIGHTS', Decimal('261.333333')),
#  ('CHATHAM', Decimal('560.222222')),
#  ('CHICAGO LAWN', Decimal('1012.285714')),
#  ('CLEARING', Decimal('521.250000')),
#  ('DOUGLAS', Decimal('424.545454')),
#  ('DUNNING', Decimal('761.333333')),
#  ('EAST GARFIELD PARK', Decimal('410.538461')),
#  ('EAST SIDE', Decimal('1061.000000')),
# ...

# %%
# %sql SELECT COMMUNITY_AREA_NAME, SAFETY_SCORE \
FROM CHICAGO_PUBLIC_SCHOOLS \
ORDER BY SAFETY_SCORE LIMIT 1
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 1)]

# %%
# %sql SELECT COMMUNITY_AREA_NAME \
FROM CHICAGO_PUBLIC_SCHOOLS \
WHERE SAFETY_SCORE = (SELECT MIN(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS)
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK',)]

# %%
# %sql SELECT MIN(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(1,)]

# %%
# %sql SELECT S.COMMUNITY_AREA_NAME, C.PER_CAPITA_INCOME  \
FROM CHICAGO_PUBLIC_SCHOOLS as S, CENSUS_DATA as C \
WHERE SAFETY_SCORE = (SELECT MIN(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS)
# Out:
#  * ibm_db_sa://gqs15811:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 23939),
#  ('WASHINGTON PARK', 28202),
#  ('WASHINGTON PARK', 33385),
#  ('WASHINGTON PARK', 25828),
#  ('WASHINGTON PARK', 27149),
#  ('WASHINGTON PARK', 34381),
#  ('WASHINGTON PARK', 19713),
#  ('WASHINGTON PARK', 39523),
#  ('WASHINGTON PARK', 15528),
#  ('WASHINGTON PARK', 23482),
#  ('WASHINGTON PARK', 17285),
#  ('WASHINGTON PARK', 11888),
#  ('WASHINGTON PARK', 11317),
#  ('WASHINGTON PARK', 13231),
#  ('WASHINGTON PARK', 16907),
#  ('WASHINGTON PARK', 25113),
#  ('WASHINGTON PARK', 12171),
#  ('WASHINGTON PARK', 15754),
#  ('WASHINGTON PARK', 12765),
#  ('WASHINGTON PARK', 22694),
#  ('WASHINGTON PARK', 16954),
#  ('WASHINGTON PARK', 13089),
#  ('WASHINGTON PARK', 16134),
#  ('WASHINGTON PARK', 26353),
#  ('WASHINGTON PARK', 22677),
#  ('WASHINGTON PARK', 8201),
#  ('WASHINGTON PARK', 16563),
#  ('WASHINGTON PARK', 17104),
# ...
